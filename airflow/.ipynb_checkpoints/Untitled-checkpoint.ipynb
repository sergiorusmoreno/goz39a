# %%
import pandas as pd
import openpyxl

# %%
df = pd.read_excel('https://epistat.sciensano.be/Data/COVID19BE.xlsx',engine='openpyxl')

# %%
df
# Out:
#             DATE        PROVINCE    REGION AGEGROUP  SEX  CASES
# 0     2020-03-01       Antwerpen  Flanders    40-49    M      1
# 1     2020-03-01        Brussels  Brussels    10-19    F      1
# 2     2020-03-01        Brussels  Brussels    10-19    M      1
# 3     2020-03-01        Brussels  Brussels    20-29    M      1
# 4     2020-03-01        Brussels  Brussels    30-39    F      1
# ...          ...             ...       ...      ...  ...    ...
# 77738        NaT   VlaamsBrabant  Flanders    40-49    M      3
# 77739        NaT   VlaamsBrabant  Flanders    50-59    M      1
# 77740        NaT  WestVlaanderen  Flanders    20-29    F      1
# 77741        NaT  WestVlaanderen  Flanders    50-59    M      3
# 77742        NaT             NaN       NaN      NaN  NaN      1
#
# [77743 rows x 6 columns]
