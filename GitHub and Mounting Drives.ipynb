# %% [markdown]
# Since we plan to store our project in our G-drive, we have to mount our google drive in to the runtime. In order to do that, type in the following in the first cell of your colab and run the cell.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# After you insert that authentication code in the provided space, your google drive will be mounted. You can check the contents of the current folder in the runtime by typing the following and running the cell.

# %%
# !ls
# Out:
# course_kul  drive  gdrive  pythonforfinance  sample_data

# %% [markdown]
# If the drive is mounted correcly, you would see that the current folder has a directory called ‘gdrive’. This is where you can find your google drive contents. Now, to access the project_folder we created earlier, type in the following and run the cell.

# %%
# %cd gdrive/My Drive/Test
# Out:
# /content/gdrive/My Drive/Test

# %% [markdown]
# Check if you are in the correct drive/place

# %%
# !pwd
# Out:
# /content/gdrive/My Drive/Test

# %% [markdown]
# Clone the directory

# %%
# !git clone https://github.com/despiegj/pythonforfinance.git course_kul
# Out:
# fatal: destination path 'course_kul' already exists and is not an empty directory.

# %%
# !ls
# Out:
# course_kul  Test.ipynb

# %% [markdown]
# Now you have successfully cloned your repository in to the google drive. For pulling the changes from the repository, you can use the following command.

# %%
# !cd course_kul

# %%
# !git pull
# Out:
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
