# %% [markdown]
# We’re going to set up the AWS cli, which is the command line interface connecting to an S3 bucket.

# %%
df = pd.read_excel("https://goz39a.s3.eu-central-1.amazonaws.com/FUT_12_35923_5.xlsx")

# %%
pd.read_csv('saksadldasjlk')
# Out:
#        orderTimeStamp  executionTimeStamp  ...  buyAmount  sellAmount
# 0 2020-06-19 10:12:01 2020-06-19 10:12:01  ...        NaN         NaN
# 1 2020-06-18 10:26:37 2020-06-18 10:26:37  ...        NaN         NaN
# 2 2020-06-18 10:15:43 2020-06-18 10:15:43  ...        NaN         NaN
# 3 2020-06-15 12:21:29 2020-06-15 12:21:29  ...        NaN         NaN
# 4 2020-06-15 12:23:05 2020-06-15 12:23:05  ...        NaN         NaN
# 5 2020-06-18 12:08:20 2020-06-18 12:08:20  ...        NaN         NaN
# 6 2020-06-18 10:06:14 2020-06-18 10:06:14  ...        NaN         NaN
# 7 2020-06-18 11:05:12 2020-06-18 11:05:12  ...        NaN         NaN
# 8 2020-06-17 12:28:47 2020-06-17 12:28:47  ...        NaN         NaN
# 9 2020-06-16 11:35:19 2020-06-16 11:35:19  ...        NaN         NaN
#
# [10 rows x 32 columns]
